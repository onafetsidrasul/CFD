# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('stream.csv')

# %%
print(df)
# Out:
#         U:0           U:1       U:2             p  IntegrationTime  \
# 0    1.0395  1.505300e-21  0.009260 -3.565800e-02         0.000000
# 1    1.0398 -3.082200e-22  0.008578 -3.602200e-02         0.001269
# 2    1.0402 -1.034900e-21  0.007885 -3.635600e-02         0.002533
# 3    1.0404 -2.914900e-22  0.007182 -3.665200e-02         0.003791
# 4    1.0407 -2.281900e-22  0.006572 -3.688300e-02         0.005050
# ..      ...           ...       ...           ...              ...
# 287  1.0046  0.000000e+00 -0.000143  1.839200e-06         0.359670
# 288  1.0046  0.000000e+00 -0.000142  1.417700e-06         0.361010
# 289  1.0046  0.000000e+00 -0.000142  9.972000e-07         0.362360
# 290  1.0046  0.000000e+00 -0.000142  5.777400e-07         0.363710
# 291  1.0046  0.000000e+00 -0.000141  1.573500e-07         0.365050
#
#       Vorticity:0  Vorticity:1   Vorticity:2      Rotation  AngularVelocity  \
# 0    2.684200e-16     -0.21494  1.279400e-14  0.000000e+00     3.823700e-16
# 1   -2.518100e-16     -0.21149 -2.370300e-14 -4.120400e-20    -4.473200e-16
# 2    8.173100e-16     -0.20882 -2.358600e-14  7.959800e-20     6.385000e-16
# 3    1.849600e-17     -0.21970  6.304700e-15  5.204600e-19     6.201300e-17
# 4    3.688900e-16     -0.32135 -7.305300e-15  7.625400e-19     3.227500e-16
# ..            ...          ...           ...           ...              ...
# 287 -2.294300e-18     -0.21068  1.581900e-14 -2.955200e-18    -4.539400e-18
# 288 -2.781700e-18     -0.21056 -1.617500e-14 -2.958600e-18    -4.933400e-19
# 289 -2.545600e-18     -0.21124 -2.910000e-14 -2.957900e-18     1.561400e-18
# 290 -2.084900e-19     -0.21493  7.587800e-15 -2.957700e-18    -1.277600e-18
# 291 -1.199400e-18     -0.21884  3.370300e-14 -2.962500e-18    -5.945300e-18
#
#         Normals:0  Normals:1     Normals:2  Points:0      Points:1  Points:2
# 0    7.058500e-21          1 -8.858500e-19  0.030000  0.000000e+00  0.072000
# 1    6.718600e-21          1 -8.446400e-19  0.031319  7.160100e-25  0.072011
# 2    7.661900e-21          1 -9.654400e-19  0.032633 -2.044000e-25  0.072022
# 3    1.031100e-10          1 -1.490100e-08  0.033942 -1.050400e-24  0.072031
# 4    1.620000e-10          1 -2.580900e-08  0.035251 -1.279900e-24  0.072040
# ..            ...        ...           ...       ...           ...       ...
# 287 -1.919000e-11          1 -1.365700e-07  0.394090  4.235600e-24  0.070021
# 288 -1.919000e-11          1 -1.365700e-07  0.395440  4.235600e-24  0.070021
# 289 -1.919000e-11          1 -1.365700e-07  0.396790  4.235600e-24  0.070021
# 290 -1.919000e-11          1 -1.365700e-07  0.398140  4.235600e-24  0.070020
# 291 -1.919000e-11          1 -1.365700e-07  0.399490  4.235600e-24  0.070020
#
# [292 rows x 16 columns]

# %%
df.style.to_html("tabella.html")

# %%
df['constant']=0.5*df['U:0']**2+df['p']+9.81*df['Points:1']

# %%
df['constant']
# Out:
# 0      0.504622
# 1      0.504570
# 2      0.504652
# 3      0.504564
# 4      0.504645
#          ...
# 287    0.504612
# 288    0.504612
# 289    0.504612
# 290    0.504611
# 291    0.504611
# Name: constant, Length: 292, dtype: float64

# %%
plt.plot(df['Points:0'],df['constant'])#[::1000]
plt.xlabel('Points:0')
plt.ylabel('Constant Value')
# Out:
# Text(0, 0.5, 'Constant Value')
