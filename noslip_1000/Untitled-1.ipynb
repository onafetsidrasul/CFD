# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('top.csv')

# %%
print(df.head())
# Out:
#       U:0           U:1       U:2         p  vtkValidPointMask  arc_length  \
# 0     NaN           NaN       NaN       NaN                  0      0.0000
# 1  1.0006 -4.637700e-23 -0.000030 -0.016444                  1      0.0003
# 2  1.0015 -1.074100e-22 -0.000079 -0.016443                  1      0.0006
# 3  1.0023 -7.471700e-24 -0.000136 -0.016442                  1      0.0009
# 4  1.0031 -9.272200e-22 -0.000199 -0.016442                  1      0.0012
#
#    Points:0  Points:1  Points:2
# 0      0.03         0   -0.1500
# 1      0.03         0   -0.1497
# 2      0.03         0   -0.1494
# 3      0.03         0   -0.1491
# 4      0.03         0   -0.1488

# %% [markdown]
# NOTE: the surface value is extracted looking at the csv file noticing the last value for 'Points:2' before the nan section.
#
# The bl value is extracted qualitatively because what is plotted is not a function but a collection of data. A look at the csv file shows similar results.
#
# Also the extraction of perpendicular lines has been done quantitatively.

# %% [markdown]
# $u_0$ is extracted from the no slip case.

# %%
df_slip= pd.read_csv('top_slip.csv')
df_slip=df_slip.dropna()
u_inf= np.mean(df_slip['U:0'])

# %%
u_inf
# Out:
# 1.049945168067227

# %%
plt.plot(df['U:0'], df['Points:2'])
plt.ylim(0.005, 0.015)
plt.axhline(y=0.0072, color='g', linestyle='--', label='surface')
plt.axvline(x=0.99*u_inf, color='b', linestyle='--', label='u=0.99 u')
plt.axhline(y=0.0122, color='r', linestyle='--', label='boundary of bl')
plt.xlabel('u_x')
plt.ylabel('distance')
plt.legend()

# %% [markdown]
# So $\delta=0.0122-0.0072=0.0050$. The theoretical value of $\delta=0.12/\sqrt(1000)=0.0038$.

# %%
df = pd.read_csv('behind.csv')

# %%
df_slip = pd.read_csv('behind_slip.csv')
df_slip = df_slip.dropna()
df_slip = df_slip[df_slip['Points:2'] > 0]
u_inf = np.mean(df_slip['U:0'])

# %%
u_inf
# Out:
# 1.026733436213992

# %%
plt.plot(df['U:0'], df['Points:2'])
plt.ylim(0.002, 0.02)
plt.axhline(y=0.0045, color='g', linestyle='--', label='surface')
plt.axvline(x=0.99*u_inf, color='b', linestyle='--', label='u=0.99 u')
plt.axhline(y=0.0156, color='r', linestyle='--', label='boundary of bl')
plt.xlabel('u_x')
plt.ylabel('distance')
plt.legend()

# %% [markdown]
# In this case $\delta= 0.0156 - 0.0045 = 0.0111$.

# %%
df = pd.read_csv('first.csv')

# %%
df_slip = pd.read_csv('first_slip.csv')
df_slip = df_slip.dropna()
df_slip = df_slip[df_slip['Points:2'] > 0]
u_inf = np.mean(df_slip['U:0'])
u_inf
# Out:
# 1.0457025531914892

# %%
plt.plot(df['U:0'], df['Points:2'])
plt.ylim(0.002, 0.0125)
plt.axhline(y=0.0069, color='g', linestyle='--', label='surface')
plt.axvline(x=0.99*u_inf, color='b', linestyle='--', label='u=0.99 u')
plt.axhline(y=0.0108, color='r', linestyle='--', label='boundary of bl')
plt.xlabel('u_x')
plt.ylabel('distance')
plt.legend()

# %% [markdown]
# In this case $\delta= 0.0108 - 0.0069 = 0.0039$.

# %%
from scipy.optimize import curve_fit
x_vals= np.linspace(0, 0.1, 100)

x=[0.0229,0.031, 0.0856]
y=[0.0039,0.005,0.0111]

def model(x, a, b):
    return a * np.sqrt(x) + b

params, _ = curve_fit(model, x, y)
a_fit, b_fit = params

y_fit = model(x_vals, a_fit, b_fit)

plt.scatter(x, y, color='red', label='data points')
plt.plot(x_vals, y_fit, color='blue', linestyle='--', label=f'Fit: {a_fit:.4f}√x  {b_fit:.4f}')
plt.xlabel('x')
plt.ylabel('delta')
plt.legend()

# %%
compare= [0.0020/0.0039,0.00257/0.005,0.0065/0.0111]
x=[0.0229,0.031, 0.0856]
plt.ylim(0, 1)
plt.scatter(x, compare, color='red', label='delta_ratio')
plt.axhline(y=0.5, color='b', linestyle='--', label='theoretical ratio')
plt.legend()
plt.xlabel('x')
plt.ylabel('delta_ratio')
# Out:
# Text(0, 0.5, 'delta_ratio')
