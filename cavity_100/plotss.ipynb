# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('xx.csv')

# %%
print(df.head())
# Out:
#         U:0      U:1  U:2         p  vtkValidPointMask  arc_length  Points:0  \
# 0  0.000000  0.00000    0  0.000575                  1       0.000     0.000
# 1 -0.000007  0.00173    0  0.000544                  1       0.001     0.001
# 2 -0.000013  0.00346    0  0.000513                  1       0.002     0.002
# 3 -0.000029  0.00516    0  0.000453                  1       0.003     0.003
# 4 -0.000045  0.00686    0  0.000393                  1       0.004     0.004
#
#    Points:1  Points:2
# 0         0     0.025
# 1         0     0.025
# 2         0     0.025
# 3         0     0.025
# 4         0     0.025

# %%
data={
    'x': [1., 0.9688, 0.9609, 0.9531, 0.9453, 0.9063, 0.8594, 0.8047, 0.5, 0.2344, 0.2266, 0.1563, 0.0938, 0.0781, 0.0703, 0.0625, 0],
    'v_y': [0., -0.05906, -0.07391, -0.08864, -0.10313, -0.16914, -0.22445, -0.24533, 0.05454, 0.17527, 0.17507, 0.16077, 0.12317, 0.10890, 0.10091, 0.09233, 0.]
}

# %%
df_paper = pd.DataFrame(data)

# %%
plt.plot(df['Points:0'], df['U:1'], label='simulation')
plt.plot(df_paper['x'], df_paper['v_y'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('v along horizontal line Re=100')
plt.xlabel('x')
plt.ylabel('v')
# Out:
# Text(0, 0.5, 'v')

# %%
x = [
    0.0100, 0.0200, 0.0300, 0.0400, 0.0500, 0.0600, 0.0700, 0.0800, 0.0900, 0.1000, 0.1100, 0.1200, 0.1300, 0.1400,
    0.1500, 0.1600, 0.1700, 0.1800, 0.1900, 0.2000, 0.2100, 0.2200, 0.2300, 0.2400, 0.2500, 0.2600, 0.2700, 0.2800,
    0.2900, 0.3000, 0.3100, 0.3200, 0.3300, 0.3400, 0.3500, 0.3600, 0.3700, 0.3800, 0.3900, 0.4000, 0.4100, 0.4200,
    0.4300, 0.4400, 0.4500, 0.4600, 0.4700, 0.4800, 0.4900, 0.5000, 0.5100, 0.5200, 0.5300, 0.5400, 0.5500, 0.5600,
    0.5700, 0.5800, 0.5900, 0.6000, 0.6100, 0.6200, 0.6300, 0.6400, 0.6500, 0.6600, 0.6700, 0.6800, 0.6900, 0.7000,
    0.7100, 0.7200, 0.7300, 0.7400, 0.7500, 0.7600, 0.7700, 0.7800, 0.7900, 0.8000, 0.8100, 0.8200, 0.8300, 0.8400,
    0.8500, 0.8600, 0.8700, 0.8800, 0.8900, 0.9000, 0.9100, 0.9200, 0.9300, 0.9400, 0.9500, 0.9600, 0.9700, 0.9800,
    0.9900, 1.0000
]

y = [
    0, 0.0165, 0.0318, 0.0461, 0.0594, 0.0716, 0.0829, 0.0932, 0.1027, 0.1113,
    0.1190, 0.1260, 0.1323, 0.1379, 0.1429, 0.1472, 0.1510, 0.1542, 0.1569, 0.1592,
    0.1610, 0.1623, 0.1633, 0.1639, 0.1641, 0.1640, 0.1635, 0.1627, 0.1616, 0.1601,
    0.1584, 0.1563, 0.1540, 0.1513, 0.1483, 0.1450, 0.1414, 0.1374, 0.1332, 0.1286,
    0.1237, 0.1184, 0.1128, 0.1068, 0.1005, 0.0938, 0.0867, 0.0793, 0.0716, 0.0634,
    0.0549, 0.0460, 0.0368, 0.0272, 0.0172, 0.0069, -0.0036, -0.0145, -0.0257, -0.0371,
    -0.0488, -0.0606, -0.0727, -0.0848, -0.0969, -0.1091, -0.1212, -0.1332, -0.1450,
    -0.1565, -0.1676, -0.1782, -0.1883, -0.1978, -0.2064, -0.2141, -0.2209, -0.2265,
    -0.2309, -0.2340, -0.2357, -0.2358, -0.2344, -0.2313, -0.2266, -0.2202, -0.2121,
    -0.2024, -0.1911, -0.1783, -0.1641, -0.1487, -0.1321, -0.1146, -0.0963, -0.0774,
    -0.0582, -0.0387, -0.0193, 0
]

df_matlab1 = pd.DataFrame({'x': x, 'y': y})

# %%
plt.plot(df_matlab1['x'], df_matlab1['y'], label='matlab')
plt.plot(df_paper['x'], df_paper['v_y'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('v along vertical line Re=100')
plt.xlabel('x')
plt.ylabel('v')
# Out:
# Text(0, 0.5, 'v')

# %%
df = pd.read_csv('yy.csv')

# %%
data={
    'y': [1., 0.9766, 0.9688, 0.9609, 0.9531, 0.8516, 0.7344, 0.6172, 0.5, 0.4531, 0.2813, 0.1719, 0.1016, 0.0703, 0.0625, 0.0547, 0],
    'v_x': [1., 0.84123, 0.78871, 0.73722, 0.68717, 0.23151, 0.00332, -0.13641, -0.20581, -0.21090, -0.15662, -0.10150, -0.06434, -0.04775, -0.04192, -0.03717, 0.]
}

# %%
df_paper = pd.DataFrame(data)

# %%
plt.plot(df['Points:1']+0.5, df['U:0'], label='simulation')
plt.plot(df_paper['y'], df_paper['v_x'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('u along horizontal line Re=100')
plt.xlabel('y')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')

# %%
x = [
    0.0100, 0.0200, 0.0300, 0.0400, 0.0500, 0.0600, 0.0700, 0.0800, 0.0900, 0.1000, 0.1100, 0.1200, 0.1300, 0.1400,
    0.1500, 0.1600, 0.1700, 0.1800, 0.1900, 0.2000, 0.2100, 0.2200, 0.2300, 0.2400, 0.2500, 0.2600, 0.2700, 0.2800,
    0.2900, 0.3000, 0.3100, 0.3200, 0.3300, 0.3400, 0.3500, 0.3600, 0.3700, 0.3800, 0.3900, 0.4000, 0.4100, 0.4200,
    0.4300, 0.4400, 0.4500, 0.4600, 0.4700, 0.4800, 0.4900, 0.5000, 0.5100, 0.5200, 0.5300, 0.5400, 0.5500, 0.5600,
    0.5700, 0.5800, 0.5900, 0.6000, 0.6100, 0.6200, 0.6300, 0.6400, 0.6500, 0.6600, 0.6700, 0.6800, 0.6900, 0.7000,
    0.7100, 0.7200, 0.7300, 0.7400, 0.7500, 0.7600, 0.7700, 0.7800, 0.7900, 0.8000, 0.8100, 0.8200, 0.8300, 0.8400,
    0.8500, 0.8600, 0.8700, 0.8800, 0.8900, 0.9000, 0.9100, 0.9200, 0.9300, 0.9400, 0.9500, 0.9600, 0.9700, 0.9800,
    0.9900, 1.0000
]

y = [
    1.0000, 0.9310, 0.8615, 0.7928, 0.7258, 0.6613, 0.6001, 0.5424, 0.4886, 0.4387,
    0.3927, 0.3504, 0.3117, 0.2763, 0.2440, 0.2143, 0.1871, 0.1620, 0.1388, 0.1172,
    0.0971, 0.0782, 0.0603, 0.0434, 0.0273, 0.0119, -0.0028, -0.0170, -0.0306, -0.0437,
    -0.0563, -0.0684, -0.0800, -0.0911, -0.1018, -0.1119, -0.1215, -0.1306, -0.1391,
    -0.1471, -0.1545, -0.1613, -0.1675, -0.1731, -0.1782, -0.1826, -0.1863, -0.1895,
    -0.1922, -0.1942, -0.1957, -0.1966, -0.1970, -0.1969, -0.1963, -0.1953, -0.1939,
    -0.1920, -0.1898, -0.1873, -0.1845, -0.1813, -0.1780, -0.1744, -0.1706, -0.1666,
    -0.1625, -0.1583, -0.1540, -0.1496, -0.1451, -0.1406, -0.1360, -0.1314, -0.1268,
    -0.1222, -0.1176, -0.1129, -0.1083, -0.1037, -0.0991, -0.0945, -0.0899, -0.0852,
    -0.0806, -0.0759, -0.0712, -0.0665, -0.0617, -0.0568, -0.0519, -0.0468, -0.0416,
    -0.0363, -0.0308, -0.0251, -0.0192, -0.0131, -0.0067, 0
]

df_matlab2 = pd.DataFrame({'x': x, 'y': y})

# %%
plt.plot(-df_matlab2['x']+1, df_matlab2['y'], label='matlab')
plt.plot(df_paper['y'], df_paper['v_x'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('u along horizontal line Re=100')
plt.xlabel('y')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')
