# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('xx.csv')

# %%
print(df.head())
# Out:
#         U:0       U:1  U:2         p  vtkValidPointMask  arc_length  Points:0  \
# 0  0.000000  0.000000    0  0.000488                  1       0.000     0.000
# 1  0.000005  0.006130    0  0.000490                  1       0.001     0.001
# 2  0.000010  0.012259    0  0.000492                  1       0.002     0.002
# 3  0.000020  0.018171    0  0.000495                  1       0.003     0.003
# 4  0.000030  0.024082    0  0.000498                  1       0.004     0.004
#
#    Points:1  Points:2
# 0         0     0.025
# 1         0     0.025
# 2         0     0.025
# 3         0     0.025
# 4         0     0.025

# %%
data={
    'x': [1., 0.9688, 0.9609, 0.9531, 0.9453, 0.9063, 0.8594, 0.8047, 0.5, 0.2344, 0.2266, 0.1563, 0.0938, 0.0781, 0.0703, 0.0625, 0],
    'v_y': [0., -0.21388, -0.27669, -0.33714, -0.39188, -0.51550, -0.42665, -0.31966, 0.02526, 0.32235, 0.33075, 0.37095, 0.32627, 0.30353, 0.29012, 0.27485, 0.]
}

# %%
df_paper = pd.DataFrame(data)

# %%
plt.plot(df['Points:0'], df['U:1'], label='simulation')
plt.plot(df_paper['x'], df_paper['v_y'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('v along horizontal line Re=1000')
plt.xlabel('x')
plt.ylabel('v')
# Out:
# Text(0, 0.5, 'v')

# %%
df = pd.read_csv('yy.csv')

# %%
data={
    'y': [1., 0.9766, 0.9688, 0.9609, 0.9531, 0.8516, 0.7344, 0.6172, 0.5, 0.4531, 0.2813, 0.1719, 0.1016, 0.0703, 0.0625, 0.0547, 0],
    'v_x': [1., 0.65928, 0.57492, 0.51117, 0.46604, 0.33304, 0.18719, 0.05702, -0.06080, -0.10648, -0.27805, -0.38289, -0.29730, -0.2222, -0.20196, -0.18109, 0.]
}

# %%
df_paper = pd.DataFrame(data)

# %%
plt.plot(df['Points:1']+0.5, df['U:0'], label='simulation')
plt.plot(df_paper['y'], df_paper['v_x'], marker='o', linestyle='None', label='paper')
plt.legend()
plt.title('u along vertical line Re=1000')
plt.xlabel('y')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')
